# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json
import psycopg2
import os
from dotenv import load_dotenv
load_dotenv()
conn = psycopg2.connect(f"dbname={os.getenv('SQL_DATABASE')} user={os.getenv('SQL_DATABASE')} password={os.getenv('SQL_PASSWORD')} host={os.getenv('SQL_HOST')} port={os.getenv('SQL_PORT')}")
from sqlalchemy import create_engine

engine = create_engine(f"postgresql+psycopg2://{os.getenv('SQL_USER')}:{os.getenv('SQL_PASSWORD')}@{os.getenv('SQL_HOST')}:{os.getenv('SQL_PORT')}/{os.getenv('SQL_DATABASE')}")

# %%
# Load GeoJSON geometry
with open("fr_department_core_geozone_v2.0.json") as f:  # replace with your file path
    geojson_data = json.load(f)

gdf = gpd.GeoDataFrame.from_features(geojson_data["features"])

# Load your deployment_state data (query result)
# Example: from CSV or database
deployment_df = pd.read_sql_query(""" SELECT 
    sdc.id AS dep_geozone_id,
    CASE WHEN sds2.nb_collectivity IS NULL THEN -1
        ELSE sds2.nb_collectivity
        END AS "Nb collectivités déployées",
    CASE
        WHEN sds2.nb_collectivity IS NULL THEN 'Non planifié'
        WHEN sds2.nb_collectivity = 0 THEN 'Déploiements à venir'
        WHEN sds2.nb_collectivity > 0 AND sds2.nb_collectivity < 3 THEN 'Communes pilotes'
        WHEN sds2.nb_collectivity >= 3 AND sds2.nb_collectivity <= 5 THEN 'Généralisation en cours'
        ELSE 'Généralisation avancée'
    END AS "Etat déploiement",
    sdc.lat AS lon,
    sdc.lon AS lat
FROM analytics.stats_departments_coords sdc
LEFT JOIN analytics.stats_deployement_s2_2025 sds2 
    ON sds2.dep_geozone_id = sdc.id;""", con=conn)

# Merge geometries with deployment data
gdf = gdf.merge(deployment_df, left_on="id", right_on="dep_geozone_id")
gdf
# Out:
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_45628\1909032059.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   deployment_df = pd.read_sql_query(""" SELECT
#                                              geometry     id        name  \
# 0   MULTIPOLYGON (((3.06940 43.70677, 3.05345 43.7...      2     Hérault
# 1   MULTIPOLYGON (((3.32363 44.07962, 3.29398 44.0...    360        Gard
# 2   MULTIPOLYGON (((-1.03252 44.65189, -1.02556 44...    363     Gironde
# 3   MULTIPOLYGON (((4.42165 46.20709, 4.38681 46.2...   1253       Rhône
# 4   MULTIPOLYGON (((4.79539 46.22007, 4.85265 46.3...   1533         Ain
# ..                                                ...    ...         ...
# 95  MULTIPOLYGON (((2.43548 49.13405, 2.45887 49.1...   1624  Val-d'Oise
# 96  MULTIPOLYGON (((-7.30600 50.65405, -7.31754 50...  36155  Guadeloupe
# 97  MULTIPOLYGON (((-7.29531 48.94557, -7.35666 48...  36156  Martinique
# 98  MULTIPOLYGON (((-7.20116 45.24048, -7.09042 45...  36160  La Réunion
# 99  MULTIPOLYGON (((-7.34191 43.16586, -7.34448 43...  36161     Mayotte
#
#    name_normalized insee_code  dep_geozone_id  Nb collectivités déployées  \
# 0          herault         34               2                          17
# 1             gard         30             360                          16
# 2          gironde         33             363                           9
# 3            rhone         69            1253                          -1
# 4              ain         01            1533                          -1
# ..             ...        ...             ...                         ...
# 95      val d oise         95            1624                          -1
# 96      guadeloupe        971           36155                          -1
# 97      martinique        972           36156                           0
# 98      la reunion        974           36160                          -1
# 99         mayotte        976           36161                          -1
#
#           Etat déploiement        lon       lat
# 0   Généralisation avancée  43.579527  3.368402
# 1   Généralisation avancée  43.993642  4.179888
# 2   Généralisation avancée  44.838929 -0.582924
# 3             Non planifié  45.871011  4.640838
# 4             Non planifié  46.099767  5.348730
# ..                     ...        ...       ...
# 95            Non planifié  49.082740  2.130828
# 96            Non planifié  51.000000 -7.223655
# 97    Déploiements à venir  49.000000 -7.223655
# 98            Non planifié  45.000000 -7.223655
# 99            Non planifié  43.000000 -7.223655
#
# [100 rows x 10 columns]

# %%
gdf[gdf["Nb collectivités déployées"]>-1]
# Out:
#                                              geometry     id  \
# 0   MULTIPOLYGON (((3.06940 43.70677, 3.05345 43.7...      2
# 1   MULTIPOLYGON (((3.32363 44.07962, 3.29398 44.0...    360
# 2   MULTIPOLYGON (((-1.03252 44.65189, -1.02556 44...    363
# 11  MULTIPOLYGON (((6.90371 43.49498, 6.88404 43.5...   1540
# 18  MULTIPOLYGON (((4.84156 43.33374, 4.58280 43.3...   1547
# 22  MULTIPOLYGON (((-1.41246 46.18445, -1.46715 46...   1551
# 36  MULTIPOLYGON (((-2.12504 48.59330, -2.15046 48...   1565
# 51  MULTIPOLYGON (((-1.86010 49.51200, -1.88908 49...   1580
# 83  MULTIPOLYGON (((6.16020 43.00186, 6.21025 43.0...   1612
# 84  MULTIPOLYGON (((4.89536 44.33817, 4.87008 44.3...   1613
# 97  MULTIPOLYGON (((-7.29531 48.94557, -7.35666 48...  36156
#
#                  name    name_normalized insee_code  dep_geozone_id  \
# 0             Hérault            herault         34               2
# 1                Gard               gard         30             360
# 2             Gironde            gironde         33             363
# 11    Alpes-Maritimes    alpes maritimes         06            1540
# 18   Bouches-du-Rhône   bouches du rhone         13            1547
# 22  Charente-Maritime  charente maritime         17            1551
# 36    Ille-et-Vilaine    ille et vilaine         35            1565
# 51             Manche             manche         50            1580
# 83                Var                var         83            1612
# 84           Vaucluse           vaucluse         84            1613
# 97         Martinique         martinique        972           36156
#
#     Nb collectivités déployées         Etat déploiement        lon       lat  \
# 0                           17   Généralisation avancée  43.579527  3.368402
# 1                           16   Généralisation avancée  43.993642  4.179888
# 2                            9   Généralisation avancée  44.838929 -0.582924
# 11                           0     Déploiements à venir  43.938066  7.116289
# 18                           0     Déploiements à venir  43.545654  5.085740
# 22                           0     Déploiements à venir  45.775048 -0.679041
# 36                           1         Communes pilotes  48.155070 -1.638137
# 51                           0     Déploiements à venir  49.080789 -1.328771
# 83                           3  Généralisation en cours  43.441723  6.244517
# 84                           3  Généralisation en cours  44.007120  5.177303
# 97                           0     Déploiements à venir  49.000000 -7.223655
#
#       color
# 0   #3399ff
# 1   #3399ff
# 2   #3399ff
# 11  #ffcc99
# 18  #ffcc99
# 22  #ffcc99
# 36  #cceeff
# 51  #ffcc99
# 83  #99ddff
# 84  #99ddff
# 97  #ffcc99

# %%
import folium
import geopandas as gpd
import json
from folium.features import DivIcon
from branca.element import MacroElement, Template
import pandas as pd
from folium import Element
# ----------------------------
# Custom color palette
# ----------------------------
state_colors = {
    'Non planifié': '#f0f0f0',          # very light gray
    'Déploiements à venir': '#ffcc99',  # light orange
    'Communes pilotes': '#cceeff',      # very light azure blue
    'Généralisation en cours': '#99ddff',  # light azure blue
    'Généralisation avancée': '#3399ff'    # medium azure blue
}

# Assign colors
gdf['color'] = gdf["Etat déploiement"].map(state_colors).fillna('#ffffff')

css = Element('<style>.leaflet-container { background-color: white; }</style>')

# ----------------------------
# Create map
# ----------------------------
m = folium.Map(
    location=[46.5, 2.5],
    zoom_start=6,
    tiles=None,
    control_scale=True,
    backGround="#ffffff"
)
m.get_root().html.add_child(css)

white_bounds = [[39, -9], [53, 12]]
# White background rectangle
folium.Rectangle(
    bounds=white_bounds,
    color="#ffffff",
    fill=True,
    fill_color="#ffffff",
    fill_opacity=1
).add_to(m)

# ----------------------------
# Add polygons and labels
# ----------------------------
for _, row in gdf.iterrows():
    sim_geo = gpd.GeoSeries(row['geometry']).simplify(0.01)
    geo_j = sim_geo.to_json()
    
    # Polygon
    folium.GeoJson(
        geo_j,
        style_function=lambda x, color=row['color']: {
            'fillColor': color,
            'color': 'black',
            'weight': 1,
            'fillOpacity': 0.85
        },
        tooltip=f"""
            <b>{row['name']}</b><br>
            Collectivités: {row['Nb collectivités déployées'] if row['Nb collectivités déployées'] is not None else 'N/A'}<br>
            État: {row['Etat déploiement'] if row['Etat déploiement'] is not None else 'N/A'}
        """
    ).add_to(m)

    # Labels (department + nb_collectivity)
    if pd.notnull(row['lat']) and pd.notnull(row['lon']):
        dep_name = row['name']
        nb_label = row.get("Nb collectivités déployées", None)
        if row['Nb collectivités déployées'] > -1:
            if row["Nb collectivités déployées"] == 0:
                label = row["name"]
            else:
                label_nb_collectivity = str(row["Nb collectivités déployées"])
                label = row["name"] + " : " + label_nb_collectivity
        else:
            label = ""  # show department name even if no deployment
            
        # Department name
        folium.map.Marker(
            [row['lon'], row['lat']],
            icon=DivIcon(
                icon_size=(150, 20),
                icon_anchor=(0, 0),
                html=f'<div class="label-name" style="text-align:left; font-weight:bold;">{label}</div>'
            )
        ).add_to(m)

# ----------------------------
# Add fixed-position legend (top-right of white rectangle)
# ----------------------------
legend_html = """
{% macro html(this, kwargs) %}
<div style="
    position: absolute;
    top: 30px;                /* push down from top */
    right: 50px;              /* push from right edge */
    background-color: rgba(255,255,255,0.95);
    border: 1px solid #aaa;
    border-radius: 8px;
    padding: 10px 12px;
    width: 190px;
    box-shadow: 0 0 8px rgba(0,0,0,0.2);
    font-family: Arial, sans-serif;
    font-size: 10pt;
    z-index: 9999;
">
<b>État déploiement</b><br>
<div style="margin-top:6px; line-height: 1.4;">
    <i style="background:#f0f0f0; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;"></i>Non planifié<br>
    <i style="background:#ffcc99; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;"></i>Déploiements à venir<br>
    <i style="background:#cceeff; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;"></i>Communes pilotes<br>
    <i style="background:#99ddff; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;"></i>Généralisation en cours<br>
    <i style="background:#3399ff; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;"></i>Généralisation avancée<br>
</div>
</div>
{% endmacro %}
"""
macro = MacroElement()
macro._template = Template(legend_html)
m.get_root().add_child(macro)

# ----------------------------
# Save to HTML
# ----------------------------
m.save("deployment_map_responsive.html")
print("✅ Map saved as 'deployment_map_responsive_v1.html'")
m
# Out:
# ✅ Map saved as 'deployment_map_responsive.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86332f79a33ead806c6ccfd8cf87b66b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;style&gt;.leaflet-container { background-color: white; }&lt;/style&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86332f79a33ead806c6ccfd8cf87b66b&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;
#     position: absolute;
#     top: 30px;                /* push down from top */
#     right: 50px;              /* push from right edge */
#     background-color: rgba(255,255,255,0.95);
#     border: 1px solid #aaa;
#     border-radius: 8px;
#     padding: 10px 12px;
#     width: 190px;
#     box-shadow: 0 0 8px rgba(0,0,0,0.2);
#     font-family: Arial, sans-serif;
#     font-size: 10pt;
#     z-index: 9999;
# &quot;&gt;
# &lt;b&gt;État déploiement&lt;/b&gt;&lt;br&gt;
# &lt;div style=&quot;margin-top:6px; line-height: 1.4;&quot;&gt;
#     &lt;i style=&quot;background:#f0f0f0; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;&quot;&gt;&lt;/i&gt;Non planifié&lt;br&gt;
#     &lt;i style=&quot;background:#ffcc99; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;&quot;&gt;&lt;/i&gt;Déploiements à venir&lt;br&gt;
#     &lt;i style=&quot;background:#cceeff; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;&quot;&gt;&lt;/i&gt;Communes pilotes&lt;br&gt;
#     &lt;i style=&quot;background:#99ddff; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;&quot;&gt;&lt;/i&gt;Généralisation en cours&lt;br&gt;
#     &lt;i style=&quot;background:#3399ff; width:18px; height:12px; float:left; margin-right:6px; border:1px solid #999;&quot;&gt;&lt;/i&gt;Généralisation avancée&lt;br&gt;
# &lt;/div&gt;
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86332f79a33ead806c6ccfd8cf87b66b = L.map(
#                 &quot;map_86332f79a33ead806c6ccfd8cf87b66b&quot;,
#                 {
#                     center: [46.5, 2.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     backGround: &quot;#ffffff&quot;,
#                 }
#             );
#             L.control.scale().addTo(map_86332f79a33ead806c6ccfd8cf87b66b);
#
#
#
#
#
#             var rectangle_07d291fc1c83e663786928fbc9c67e4c = L.rectangle(
#                 [[39.0, -9.0], [53.0, 12.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86332f79a33ead806c6ccfd8cf87b66b);
#
#
#         function geo_json_4e78be7ce714025db5cebd737e43477f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3399ff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4e78be7ce714025db5cebd737e43477f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4e78be7ce714025db5cebd737e43477f = L.geoJson(null, {
#                 onEachFeature: geo_json_4e78be7ce714025db5cebd737e43477f_onEachFeature,
#
#                 style: geo_json_4e78be7ce714025db5cebd737e43477f_styler,
#         });
#
#         function geo_json_4e78be7ce714025db5cebd737e43477f_add (data) {
#             geo_json_4e78be7ce714025db5cebd737e43477f
#                 .addData(data);
#         }
#             geo_json_4e78be7ce714025db5cebd737e43477f_add({&quot;bbox&quot;: [2.539556383, 43.210196594, 4.194546281, 43.97275315], &quot;features&quot;: [{&quot;bbox&quot;: [2.539556383, 43.210196594, 4.194546281, 43.97275315], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[3.069399418, 43.706774641], [3.053450486, 43.716292161], [3.052461496, 43.745845286], [3.075963596, 43.768473668], [3.048638386, 43.801295101], [3.06363599, 43.809046194], [3.064766944, 43.835524051], [3.212828203, 43.813418607], [3.249141754, 43.829657757], [3.234606934, 43.861578374], [3.264999347, 43.895278728], [3.342999396, 43.894314622], [3.369988051, 43.917264354], [3.437829601, 43.901097767], [3.441876844, 43.887544433], [3.422091169, 43.872660314], [3.43177657, 43.863038135], [3.505346856, 43.897303573], [3.522903605, 43.888425663], [3.52837016, 43.853996346], [3.57886336, 43.843613206], [3.600533863, 43.84944554], [3.574868341, 43.865497399], [3.623571379, 43.916882368], [3.638844059, 43.916115532], [3.639278153, 43.896181338], [3.640928549, 43.915593934], [3.671446579, 43.909640846], [3.685561098, 43.953824518], [3.752133631, 43.97275315], [3.78768928, 43.96680835], [3.795514148, 43.942274943], [3.827000456, 43.936192042], [3.80388128, 43.879193687], [3.851875943, 43.8675287], [3.916878868, 43.887855552], [3.922127049, 43.858368352], [3.980649043, 43.843113745], [3.959173317, 43.805036469], [4.018397406, 43.807627599], [4.114235504, 43.737700525], [4.141683212, 43.737876093], [4.194546281, 43.653933713], [4.150240576, 43.585445224], [4.074694959, 43.588555823], [4.108303757, 43.569923479], [4.09914437, 43.552851476], [3.974962798, 43.546722337
